# %%
# !nvidia-smi
# Out:
# Sun May 24 15:34:01 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   68C    P8    32W / 149W |      0MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
from IPython.display import clear_output
from google.colab import output
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
os.chdir('/content/drive/My Drive')
project_folder = 'BACR_Project'
Controller_folder = 'Controller'
if not os.path.exists(os.path.join(project_folder, Controller_folder)):
  os.mkdir(project_folder)
os.chdir(project_folder)
if not os.path.exists(Controller_folder):
  os.mkdir(Controller_folder)  
os.chdir(Controller_folder)
# !pwd
# Out:
# /content/drive/My Drive/BACR_Project/Controller

# %% [markdown]
# # Install dependencies

# %%
# !apt-get update && apt-get upgrade -y
# !apt-get install -y software-properties-common
# !apt-get update && apt-get install -y freeglut3-dev git
# !apt-get update --fix-missing && apt-get install -y \
      python3-numpy python3-matplotlib python3-dev \
      python3-opengl python3-pip \
      cmake zlib1g-dev libjpeg-dev xvfb libpq-dev \
      xorg-dev libboost-all-dev libsdl2-dev swig \
      git wget openjdk-8-jdk ffmpeg unzip\
    && apt-get clean && rm -rf /var/cache/apt/archives/* /var/lib/apt/lists/*
# !pip3 install --upgrade pip
# !pip3 install h5py future pyvirtualdisplay 'gym[atari]' 'gym[box2d]' 'gym[classic_control]' opencv-python
# !pip3 install torch torchvision tensorflow-gpu==1.8 pandas filelock
# !pip3 install pybullet==2.5.0
# !sed -i 's/robot_bases/pybullet_envs.robot_bases/' /usr/local/lib/python3.5/dist-packages/pybullet_envs/robot_locomotors.py
# !apt-get update && apt-get install libgsl0-dev -y
# !pip3 install pyglet Cython
# !git clone https://github.com/snolfi/evorobotpy.git
# !cd evorobotpy/lib/ \
    && python3 setupevonet.py build_ext --inplace \
    && cp net*.so ../bin
# !cd evorobotpy/lib/ \
    && python3 setupErDiscrim.py build_ext --inplace \
    && cp ErDiscrim*.so ../bin
!сd evorobotpy/lib/ \
    && python3 setupErPredprey.py build_ext --inplace \
    && cp ErPredprey*.so ../bin   
# !cd evorobotpy/lib/ \
    && python3 setupErDpole.py build_ext --inplace \
    && cp ErDpole*.so ../bin
# !pip3 install notebook
# !git clone --depth 1 https://github.com/openai/baselines.git \
    && sed --in-place 's/mujoco,//' baselines/setup.py \
    && cd baselines && pip3 install -e . \
    && pip3 install mpi4py cloudpickle             
output.clear()

# %% [markdown]
# # Clone our repository

# %%
os.chdir('/content/drive/My Drive/BACR_Project/Controller')
# !git clone https://github.com/Terminateit/BACR_MIT_CAR
% cd BACR_MIT_CAR/
# !git checkout controller
# Out:
# Cloning into 'BACR_MIT_CAR'...
# remote: Enumerating objects: 3798, done.
# remote: Counting objects: 100% (3798/3798), done.
# remote: Compressing objects: 100% (411/411), done.
# remote: Total 3798 (delta 3482), reused 3686 (delta 3380), pack-reused 0
# Receiving objects: 100% (3798/3798), 45.31 MiB | 11.14 MiB/s, done.
# Resolving deltas: 100% (3482/3482), done.
# Checking out files: 100% (151/151), done.
# /content/drive/My Drive/BACR_Project/Controller/BACR_MIT_CAR
# Branch 'controller_dev' set up to track remote branch 'controller_dev' from 'origin'.
# Switched to a new branch 'controller_dev'

# %% [markdown]
# # Substitute files

# %%
% cd controller 
# !cp controller.py ../../evorobotpy/bin/
# !cp es.py ../../evorobotpy/bin/
# !cp es_car.py ../../evorobotpy/bin/
# !cp policy_car.py ../../evorobotpy/bin/
# !cp mdrnn.py ../../evorobotpy/bin/
# !cp vae.py ../../evorobotpy/bin/

#folder 
! cp -r models_dir ../../evorobotpy/bin/
# Out:
# /content/drive/My Drive/BACR_Project/Controller/BACR_MIT_CAR/controller

# %% [markdown]
# # Build the env

# %%
% cd /content/drive/My Drive/BACR_Project/Controller/BACR_MIT_CAR/racecar
! pip3 install -e.
# Out:
# /content/drive/My Drive/BACR_Project/Controller/BACR_MIT_CAR/racecar
# Obtaining file:///content/drive/My%20Drive/BACR_Project/Controller/BACR_MIT_CAR/racecar
# Requirement already satisfied: gym in /usr/local/lib/python3.6/dist-packages (from racecar==0.0.1) (0.15.7)
# Requirement already satisfied: pybullet in /usr/local/lib/python3.6/dist-packages (from racecar==0.0.1) (2.5.0)
# Collecting cloudpickle~=1.2.0
#   Downloading cloudpickle-1.2.2-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym->racecar==0.0.1) (1.18.4)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from gym->racecar==0.0.1) (1.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from gym->racecar==0.0.1) (1.12.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym->racecar==0.0.1) (1.4.1)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym->racecar==0.0.1) (0.16.0)
# Installing collected packages: racecar, cloudpickle
#   Running setup.py develop for racecar
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 1.3.0
#     Uninstalling cloudpickle-1.3.0:
#       Successfully uninstalled cloudpickle-1.3.0
# Successfully installed cloudpickle-1.2.2 racecar

# %% [markdown]
# # Build NET

# %%
% cd /content/drive/My Drive/BACR_Project/Controller/evorobotpy/lib
! python3 setupevonet.py build_ext --inplace
# !cp net*.so ../bin # or cp net*.dll ../bin
# Out:
# /content/drive/My Drive/BACR_Project/Controller/evorobotpy/lib
# running build_ext
# skipping 'net.cpp' Cython extension (up-to-date)

# %% [markdown]
# # Launch es_car.py
#
# Change the .ini and .npy file here.

# %%
% cd /content/drive/My Drive/BACR_Project/Controller/BACR_MIT_CAR/training_results
! python3 ../../evorobotpy/bin/es_car.py -f racecar15.ini -t bestgS15.npy
# Out:
# /content/drive/My Drive/BACR_Project/Controller/BACR_MIT_CAR/training_results
# Environment racecar-v2 nreplications 1 maxmsteps 50m
# pybullet build time: May 24 2020 15:38:07
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float64
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Car Gym policy
# Evaluation: Episodes 1 Test Episodes 1 MaxSteps 100000
# Network 288->100->3 recurrent with bias tanh output:linear init:xavier input-normalization output-diagonal-gaussian
# Run Test: Environment racecar-v2 testfile bestgS15.npy
# Snapshot 1 is saved.
# Snapshot 2 is saved.
# Snapshot 3 is saved.
# Snapshot 4 is saved.
# Snapshot 5 is saved.
# Snapshot 6 is saved.
# Snapshot 7 is saved.
# Snapshot 8 is saved.
# Snapshot 9 is saved.
# Snapshot 10 is saved.
# Snapshot 11 is saved.
# Snapshot 12 is saved.
# Snapshot 13 is saved.
# Snapshot 14 is saved.
# Snapshot 15 is saved.
# Snapshot 16 is saved.
# Snapshot 17 is saved.
# Snapshot 18 is saved.
# Snapshot 19 is saved.
# Snapshot 20 is saved.
# Snapshot 21 is saved.
# Snapshot 22 is saved.
# Snapshot 23 is saved.
# Snapshot 24 is saved.
# Snapshot 25 is saved.
# Snapshot 26 is saved.
# Snapshot 27 is saved.
# Snapshot 28 is saved.
# Snapshot 29 is saved.
# Snapshot 30 is saved.
# Snapshot 31 is saved.
# Snapshot 32 is saved.
# Snapshot 33 is saved.
# Snapshot 34 is saved.
# Snapshot 35 is saved.
# Snapshot 36 is saved.
# Snapshot 37 is saved.
# Snapshot 38 is saved.
# Snapshot 39 is saved.
# Snapshot 40 is saved.
# Snapshot 41 is saved.
# Snapshot 42 is saved.
# Snapshot 43 is saved.
# Snapshot 44 is saved.
# Snapshot 45 is saved.
# Snapshot 46 is saved.
# Snapshot 47 is saved.
# Snapshot 48 is saved.
# Snapshot 49 is saved.
# Snapshot 50 is saved.
# Snapshot 51 is saved.
# Snapshot 52 is saved.
# Snapshot 53 is saved.
# Snapshot 54 is saved.
# Snapshot 55 is saved.
# Snapshot 56 is saved.
# Snapshot 57 is saved.
# Snapshot 58 is saved.
# Snapshot 59 is saved.
# Snapshot 60 is saved.
# Snapshot 61 is saved.
# Snapshot 62 is saved.
# Snapshot 63 is saved.
# Snapshot 64 is saved.
# Snapshot 65 is saved.
# Snapshot 66 is saved.
# Snapshot 67 is saved.
# Snapshot 68 is saved.
# Snapshot 69 is saved.
# Snapshot 70 is saved.
# Snapshot 71 is saved.
# Snapshot 72 is saved.
# Snapshot 73 is saved.
# Snapshot 74 is saved.
# Snapshot 75 is saved.
# Snapshot 76 is saved.
# Snapshot 77 is saved.
# Snapshot 78 is saved.
# Snapshot 79 is saved.
# Snapshot 80 is saved.
# Snapshot 81 is saved.
# Snapshot 82 is saved.
# Snapshot 83 is saved.
# Snapshot 84 is saved.
# Snapshot 85 is saved.
# Snapshot 86 is saved.
# Snapshot 87 is saved.
# Snapshot 88 is saved.
# Snapshot 89 is saved.
# Snapshot 90 is saved.
# Snapshot 91 is saved.
# Snapshot 92 is saved.
# Snapshot 93 is saved.
# Snapshot 94 is saved.
# Snapshot 95 is saved.
# Snapshot 96 is saved.
# Snapshot 97 is saved.
# Snapshot 98 is saved.
# Snapshot 99 is saved.
# Snapshot 100 is saved.
# Snapshot 101 is saved.
# Snapshot 102 is saved.
# Snapshot 103 is saved.
# Snapshot 104 is saved.
# Snapshot 105 is saved.
# Snapshot 106 is saved.
# Snapshot 107 is saved.
# Snapshot 108 is saved.
# Snapshot 109 is saved.
# Snapshot 110 is saved.
# Snapshot 111 is saved.
# Snapshot 112 is saved.
# Snapshot 113 is saved.
# Snapshot 114 is saved.
# Snapshot 115 is saved.
# Snapshot 116 is saved.
# Snapshot 117 is saved.
# Snapshot 118 is saved.
# Snapshot 119 is saved.
# Snapshot 120 is saved.
# Snapshot 121 is saved.
# Snapshot 122 is saved.
# Snapshot 123 is saved.
# Snapshot 124 is saved.
# Snapshot 125 is saved.
# Snapshot 126 is saved.
# Snapshot 127 is saved.
# Snapshot 128 is saved.
# Snapshot 129 is saved.
# Snapshot 130 is saved.
# Snapshot 131 is saved.
# Snapshot 132 is saved.
# Snapshot 133 is saved.
# Snapshot 134 is saved.
# Snapshot 135 is saved.
# Snapshot 136 is saved.
# Snapshot 137 is saved.
# Snapshot 138 is saved.
# Snapshot 139 is saved.
# Snapshot 140 is saved.
# Snapshot 141 is saved.
# Snapshot 142 is saved.
# Snapshot 143 is saved.
# Snapshot 144 is saved.
# Snapshot 145 is saved.
# Snapshot 146 is saved.
# Snapshot 147 is saved.
# Snapshot 148 is saved.
# Snapshot 149 is saved.
# Snapshot 150 is saved.
# Snapshot 151 is saved.
# Snapshot 152 is saved.
# Snapshot 153 is saved.
# Snapshot 154 is saved.
# Snapshot 155 is saved.
# Snapshot 156 is saved.
# Snapshot 157 is saved.
# Snapshot 158 is saved.
# Snapshot 159 is saved.
# Snapshot 160 is saved.
# Snapshot 161 is saved.
# Snapshot 162 is saved.
# Snapshot 163 is saved.
# Snapshot 164 is saved.
# Snapshot 165 is saved.
# Snapshot 166 is saved.
# Snapshot 167 is saved.
# Snapshot 168 is saved.
# Snapshot 169 is saved.
# Snapshot 170 is saved.
# Snapshot 171 is saved.
# Snapshot 172 is saved.
# Snapshot 173 is saved.
# Snapshot 174 is saved.
# Snapshot 175 is saved.
# Snapshot 176 is saved.
# Snapshot 177 is saved.
# Snapshot 178 is saved.
# Snapshot 179 is saved.
# Snapshot 180 is saved.
# Snapshot 181 is saved.
# Snapshot 182 is saved.
# Snapshot 183 is saved.
# Snapshot 184 is saved.
# Snapshot 185 is saved.
# Snapshot 186 is saved.
# Snapshot 187 is saved.
# Snapshot 188 is saved.
# Snapshot 189 is saved.
# Snapshot 190 is saved.
# Snapshot 191 is saved.
# Snapshot 192 is saved.
# Snapshot 193 is saved.
# Snapshot 194 is saved.
# Snapshot 195 is saved.
# Snapshot 196 is saved.
# Snapshot 197 is saved.
# Snapshot 198 is saved.
# Snapshot 199 is saved.
# Snapshot 200 is saved.
# Snapshot 201 is saved.
# Snapshot 202 is saved.
# Snapshot 203 is saved.
# Snapshot 204 is saved.
# Snapshot 205 is saved.
# Snapshot 206 is saved.
# Snapshot 207 is saved.
# Snapshot 208 is saved.
# Snapshot 209 is saved.
# Snapshot 210 is saved.
# Snapshot 211 is saved.
# Snapshot 212 is saved.
# Snapshot 213 is saved.
# Snapshot 214 is saved.
# Snapshot 215 is saved.
# Snapshot 216 is saved.
# Snapshot 217 is saved.
# Snapshot 218 is saved.
# Snapshot 219 is saved.
# Snapshot 220 is saved.
# Snapshot 221 is saved.
# Snapshot 222 is saved.
# Snapshot 223 is saved.
# Snapshot 224 is saved.
# Snapshot 225 is saved.
# Snapshot 226 is saved.
# Snapshot 227 is saved.
# Snapshot 228 is saved.
# Snapshot 229 is saved.
# Snapshot 230 is saved.
# Snapshot 231 is saved.
# Snapshot 232 is saved.
# Snapshot 233 is saved.
# Snapshot 234 is saved.
# Snapshot 235 is saved.
# Snapshot 236 is saved.
# Snapshot 237 is saved.
# Snapshot 238 is saved.
# Snapshot 239 is saved.
# Snapshot 240 is saved.
# Snapshot 241 is saved.
# Snapshot 242 is saved.
# Snapshot 243 is saved.
# Snapshot 244 is saved.
# Snapshot 245 is saved.
# Snapshot 246 is saved.
# Snapshot 247 is saved.
# Snapshot 248 is saved.
# Snapshot 249 is saved.
# Snapshot 250 is saved.
# Snapshot 251 is saved.
# Snapshot 252 is saved.
# Snapshot 253 is saved.
# Snapshot 254 is saved.
# Snapshot 255 is saved.
# Snapshot 256 is saved.
# Snapshot 257 is saved.
# Snapshot 258 is saved.
# Snapshot 259 is saved.
# Snapshot 260 is saved.
# Snapshot 261 is saved.
# Snapshot 262 is saved.
# Snapshot 263 is saved.
# Snapshot 264 is saved.
# Snapshot 265 is saved.
# Snapshot 266 is saved.
# Snapshot 267 is saved.
# Snapshot 268 is saved.
# Snapshot 269 is saved.
# Snapshot 270 is saved.
# Snapshot 271 is saved.
# Snapshot 272 is saved.
# Snapshot 273 is saved.
# Snapshot 274 is saved.
# Snapshot 275 is saved.
# Snapshot 276 is saved.
# Snapshot 277 is saved.
# Snapshot 278 is saved.
# Snapshot 279 is saved.
# Snapshot 280 is saved.
# Snapshot 281 is saved.
# Snapshot 282 is saved.
# Snapshot 283 is saved.
# Snapshot 284 is saved.
# Snapshot 285 is saved.
# Snapshot 286 is saved.
# Snapshot 287 is saved.
# Snapshot 288 is saved.
# Snapshot 289 is saved.
# Snapshot 290 is saved.
# Snapshot 291 is saved.
# Snapshot 292 is saved.
# Snapshot 293 is saved.
# Snapshot 294 is saved.
# Snapshot 295 is saved.
# Snapshot 296 is saved.
# Snapshot 297 is saved.
# Snapshot 298 is saved.
# Snapshot 299 is saved.
# Snapshot 300 is saved.
# Snapshot 301 is saved.
# Snapshot 302 is saved.
# Snapshot 303 is saved.
# Snapshot 304 is saved.
# Snapshot 305 is saved.
# Snapshot 306 is saved.
# Snapshot 307 is saved.
# Snapshot 308 is saved.
# Snapshot 309 is saved.
# Snapshot 310 is saved.
# Snapshot 311 is saved.
# Snapshot 312 is saved.
# Snapshot 313 is saved.
# Snapshot 314 is saved.
# Snapshot 315 is saved.
# Snapshot 316 is saved.
# Snapshot 317 is saved.
# Snapshot 318 is saved.
# Snapshot 319 is saved.
# Snapshot 320 is saved.
# Snapshot 321 is saved.
# Snapshot 322 is saved.
# Snapshot 323 is saved.
# Snapshot 324 is saved.
# Snapshot 325 is saved.
# Snapshot 326 is saved.
# Snapshot 327 is saved.
# Snapshot 328 is saved.
# Snapshot 329 is saved.
# Snapshot 330 is saved.
# Snapshot 331 is saved.
# Snapshot 332 is saved.
# Snapshot 333 is saved.
# Snapshot 334 is saved.
# Snapshot 335 is saved.
# Snapshot 336 is saved.
# Snapshot 337 is saved.
# Snapshot 338 is saved.
# Snapshot 339 is saved.
# Snapshot 340 is saved.
# Snapshot 341 is saved.
# Snapshot 342 is saved.
# Snapshot 343 is saved.
# Snapshot 344 is saved.
# Snapshot 345 is saved.
# Snapshot 346 is saved.
# Snapshot 347 is saved.
# Snapshot 348 is saved.
# Snapshot 349 is saved.
# Snapshot 350 is saved.
# Snapshot 351 is saved.
# Snapshot 352 is saved.
# Snapshot 353 is saved.
# Snapshot 354 is saved.
# Snapshot 355 is saved.
# Snapshot 356 is saved.
# Snapshot 357 is saved.
# Snapshot 358 is saved.
# Snapshot 359 is saved.
# Snapshot 360 is saved.
# Snapshot 361 is saved.
# Snapshot 362 is saved.
# Snapshot 363 is saved.
# Snapshot 364 is saved.
# Snapshot 365 is saved.
# Snapshot 366 is saved.
# Snapshot 367 is saved.
# Snapshot 368 is saved.
# Snapshot 369 is saved.
# Snapshot 370 is saved.
# Snapshot 371 is saved.
# Snapshot 372 is saved.
# Snapshot 373 is saved.
# Snapshot 374 is saved.
# Snapshot 375 is saved.
# Snapshot 376 is saved.
# Snapshot 377 is saved.
# Snapshot 378 is saved.
# Snapshot 379 is saved.
# Snapshot 380 is saved.
# Snapshot 381 is saved.
# Snapshot 382 is saved.
# Snapshot 383 is saved.
# Snapshot 384 is saved.
# Snapshot 385 is saved.
# Snapshot 386 is saved.
# Snapshot 387 is saved.
# Snapshot 388 is saved.
# Snapshot 389 is saved.
# Snapshot 390 is saved.
# Snapshot 391 is saved.
# Snapshot 392 is saved.
# Snapshot 393 is saved.
# Snapshot 394 is saved.
# Snapshot 395 is saved.
# Snapshot 396 is saved.
# Snapshot 397 is saved.
# Snapshot 398 is saved.
# Snapshot 399 is saved.
# Snapshot 400 is saved.
# Snapshot 401 is saved.
# Snapshot 402 is saved.
# Snapshot 403 is saved.
# Snapshot 404 is saved.
# Snapshot 405 is saved.
# Snapshot 406 is saved.
# Snapshot 407 is saved.
# Snapshot 408 is saved.
# Snapshot 409 is saved.
# Snapshot 410 is saved.
# Snapshot 411 is saved.
# Snapshot 412 is saved.
# Snapshot 413 is saved.
# Snapshot 414 is saved.
# Snapshot 415 is saved.
# Snapshot 416 is saved.
# Snapshot 417 is saved.
# Snapshot 418 is saved.
# Snapshot 419 is saved.
# Snapshot 420 is saved.
# Snapshot 421 is saved.
# Snapshot 422 is saved.
# Snapshot 423 is saved.
# Snapshot 424 is saved.
# Snapshot 425 is saved.
# Snapshot 426 is saved.
# Snapshot 427 is saved.
# Snapshot 428 is saved.
# Snapshot 429 is saved.
# Snapshot 430 is saved.
# Snapshot 431 is saved.
# Snapshot 432 is saved.
# Snapshot 433 is saved.
# Snapshot 434 is saved.
# Snapshot 435 is saved.
# Snapshot 436 is saved.
# Snapshot 437 is saved.
# Snapshot 438 is saved.
# Snapshot 439 is saved.
# Snapshot 440 is saved.
# Snapshot 441 is saved.
# Snapshot 442 is saved.
# Snapshot 443 is saved.
# Snapshot 444 is saved.
# Snapshot 445 is saved.
# Snapshot 446 is saved.
# Snapshot 447 is saved.
# Snapshot 448 is saved.
# Snapshot 449 is saved.
# Snapshot 450 is saved.
# Snapshot 451 is saved.
# Snapshot 452 is saved.
# Snapshot 453 is saved.
# Snapshot 454 is saved.
# Snapshot 455 is saved.
# Snapshot 456 is saved.
# Snapshot 457 is saved.
# Snapshot 458 is saved.
# Snapshot 459 is saved.
# Snapshot 460 is saved.
# Snapshot 461 is saved.
# Snapshot 462 is saved.
# Snapshot 463 is saved.
# Snapshot 464 is saved.
# Snapshot 465 is saved.
# Snapshot 466 is saved.
# Snapshot 467 is saved.
# Snapshot 468 is saved.
# Snapshot 469 is saved.
# Snapshot 470 is saved.
# Snapshot 471 is saved.
# Snapshot 472 is saved.
# Snapshot 473 is saved.
# Snapshot 474 is saved.
# Snapshot 475 is saved.
# Snapshot 476 is saved.
# Snapshot 477 is saved.
# Snapshot 478 is saved.
# Snapshot 479 is saved.
# Snapshot 480 is saved.
# Snapshot 481 is saved.
# Snapshot 482 is saved.
# Snapshot 483 is saved.
# Snapshot 484 is saved.
# Snapshot 485 is saved.
# Snapshot 486 is saved.
# Snapshot 487 is saved.
# Snapshot 488 is saved.
# Snapshot 489 is saved.
# Snapshot 490 is saved.
# Snapshot 491 is saved.
# Snapshot 492 is saved.
# Snapshot 493 is saved.
# Snapshot 494 is saved.
# Snapshot 495 is saved.
# Snapshot 496 is saved.
# Snapshot 497 is saved.
# Snapshot 498 is saved.
# Snapshot 499 is saved.
# Snapshot 500 is saved.
# Snapshot 501 is saved.
# Snapshot 502 is saved.
# Snapshot 503 is saved.
# Snapshot 504 is saved.
# Snapshot 505 is saved.
# Snapshot 506 is saved.
# Snapshot 507 is saved.
# Snapshot 508 is saved.
# Snapshot 509 is saved.
# Snapshot 510 is saved.
# Snapshot 511 is saved.
# Snapshot 512 is saved.
# Snapshot 513 is saved.
# Snapshot 514 is saved.
# Snapshot 515 is saved.
# Snapshot 516 is saved.
# Snapshot 517 is saved.
# Snapshot 518 is saved.
# Snapshot 519 is saved.
# Snapshot 520 is saved.
# Snapshot 521 is saved.
# Snapshot 522 is saved.
# Snapshot 523 is saved.
# Snapshot 524 is saved.
# Snapshot 525 is saved.
# Snapshot 526 is saved.
# Snapshot 527 is saved.
# Snapshot 528 is saved.
# Snapshot 529 is saved.
# Snapshot 530 is saved.
# Snapshot 531 is saved.
# Snapshot 532 is saved.
# Snapshot 533 is saved.
# Snapshot 534 is saved.
# Snapshot 535 is saved.
# Snapshot 536 is saved.
# Snapshot 537 is saved.
# Snapshot 538 is saved.
# Snapshot 539 is saved.
# Snapshot 540 is saved.
# Snapshot 541 is saved.
# Snapshot 542 is saved.
# Snapshot 543 is saved.
# Snapshot 544 is saved.
# Snapshot 545 is saved.
# Snapshot 546 is saved.
# Snapshot 547 is saved.
# Snapshot 548 is saved.
# Snapshot 549 is saved.
# Snapshot 550 is saved.
# Snapshot 551 is saved.
# Snapshot 552 is saved.
# Snapshot 553 is saved.
# Snapshot 554 is saved.
# Snapshot 555 is saved.
# Snapshot 556 is saved.
# Snapshot 557 is saved.
# Snapshot 558 is saved.
# Snapshot 559 is saved.
# Snapshot 560 is saved.
# Snapshot 561 is saved.
# Snapshot 562 is saved.
# Snapshot 563 is saved.
# Snapshot 564 is saved.
# Snapshot 565 is saved.
# Snapshot 566 is saved.
# Snapshot 567 is saved.
# Snapshot 568 is saved.
# Snapshot 569 is saved.
# Snapshot 570 is saved.
# Snapshot 571 is saved.
# Snapshot 572 is saved.
# Snapshot 573 is saved.
# Snapshot 574 is saved.
# Snapshot 575 is saved.
# Snapshot 576 is saved.
# Snapshot 577 is saved.
# Snapshot 578 is saved.
# Snapshot 579 is saved.
# Snapshot 580 is saved.
# Snapshot 581 is saved.
# Snapshot 582 is saved.
# Snapshot 583 is saved.
# Snapshot 584 is saved.
# Snapshot 585 is saved.
# Snapshot 586 is saved.
# Snapshot 587 is saved.
# Snapshot 588 is saved.
# Snapshot 589 is saved.
# Snapshot 590 is saved.
# Snapshot 591 is saved.
# Snapshot 592 is saved.
# Snapshot 593 is saved.
# Snapshot 594 is saved.
# Snapshot 595 is saved.
# Snapshot 596 is saved.
# Snapshot 597 is saved.
# Snapshot 598 is saved.
# Snapshot 599 is saved.
# Snapshot 600 is saved.
# Snapshot 601 is saved.
# Snapshot 602 is saved.
# Snapshot 603 is saved.
# Snapshot 604 is saved.
# Snapshot 605 is saved.
# Snapshot 606 is saved.
# Snapshot 607 is saved.
# Snapshot 608 is saved.
# Snapshot 609 is saved.
# Snapshot 610 is saved.
# Snapshot 611 is saved.
# Snapshot 612 is saved.
# Snapshot 613 is saved.
# Snapshot 614 is saved.
# Snapshot 615 is saved.
# Snapshot 616 is saved.
# Snapshot 617 is saved.
# Snapshot 618 is saved.
# Snapshot 619 is saved.
# Snapshot 620 is saved.
# Snapshot 621 is saved.
# Snapshot 622 is saved.
# Snapshot 623 is saved.
# Snapshot 624 is saved.
# Snapshot 625 is saved.
# Snapshot 626 is saved.
# Snapshot 627 is saved.
# Snapshot 628 is saved.
# Snapshot 629 is saved.
# Snapshot 630 is saved.
# Snapshot 631 is saved.
# Snapshot 632 is saved.
# Snapshot 633 is saved.
# Snapshot 634 is saved.
# Snapshot 635 is saved.
# Snapshot 636 is saved.
# Snapshot 637 is saved.
# Snapshot 638 is saved.
# Snapshot 639 is saved.
# Snapshot 640 is saved.
# Snapshot 641 is saved.
# Snapshot 642 is saved.
# Snapshot 643 is saved.
# Snapshot 644 is saved.
# Snapshot 645 is saved.
# Snapshot 646 is saved.
# Snapshot 647 is saved.
# Snapshot 648 is saved.
# Snapshot 649 is saved.
# Snapshot 650 is saved.
# Snapshot 651 is saved.
# Snapshot 652 is saved.
# Snapshot 653 is saved.
# Snapshot 654 is saved.
# Snapshot 655 is saved.
# Snapshot 656 is saved.
# Snapshot 657 is saved.
# Snapshot 658 is saved.
# Snapshot 659 is saved.
# Snapshot 660 is saved.
# Snapshot 661 is saved.
# Snapshot 662 is saved.
# Snapshot 663 is saved.
# Snapshot 664 is saved.
# Snapshot 665 is saved.
# Snapshot 666 is saved.
# Snapshot 667 is saved.
# Snapshot 668 is saved.
# Snapshot 669 is saved.
# Snapshot 670 is saved.
# Snapshot 671 is saved.
# Snapshot 672 is saved.
# Snapshot 673 is saved.
# Snapshot 674 is saved.
# Snapshot 675 is saved.
# Snapshot 676 is saved.
# Snapshot 677 is saved.
# Snapshot 678 is saved.
# Snapshot 679 is saved.
# Snapshot 680 is saved.
# Snapshot 681 is saved.
# Snapshot 682 is saved.
# Snapshot 683 is saved.
# Snapshot 684 is saved.
# Snapshot 685 is saved.
# Snapshot 686 is saved.
# Snapshot 687 is saved.
# Snapshot 688 is saved.
# Snapshot 689 is saved.
# Snapshot 690 is saved.
# Snapshot 691 is saved.
# Snapshot 692 is saved.
# Snapshot 693 is saved.
# Snapshot 694 is saved.
# Snapshot 695 is saved.
# Snapshot 696 is saved.
# Snapshot 697 is saved.
# Snapshot 698 is saved.
# Snapshot 699 is saved.
# Snapshot 700 is saved.
# Snapshot 701 is saved.
# Snapshot 702 is saved.
# Snapshot 703 is saved.
# Snapshot 704 is saved.
# Snapshot 705 is saved.
# Snapshot 706 is saved.
# Snapshot 707 is saved.
# Snapshot 708 is saved.
# Snapshot 709 is saved.
# Snapshot 710 is saved.
# Snapshot 711 is saved.
# Snapshot 712 is saved.
# Snapshot 713 is saved.
# Snapshot 714 is saved.
# Snapshot 715 is saved.
# Snapshot 716 is saved.
# Snapshot 717 is saved.
# Snapshot 718 is saved.
# Snapshot 719 is saved.
# Snapshot 720 is saved.
# Snapshot 721 is saved.
# Snapshot 722 is saved.
# Snapshot 723 is saved.
# Snapshot 724 is saved.
# Snapshot 725 is saved.
# Snapshot 726 is saved.
# Snapshot 727 is saved.
# Snapshot 728 is saved.
# Snapshot 729 is saved.
# Snapshot 730 is saved.
# Snapshot 731 is saved.
# Snapshot 732 is saved.
# Snapshot 733 is saved.
# Snapshot 734 is saved.
# Snapshot 735 is saved.
# Snapshot 736 is saved.
# Snapshot 737 is saved.
# Snapshot 738 is saved.
# Snapshot 739 is saved.
# Snapshot 740 is saved.
# Snapshot 741 is saved.
# Snapshot 742 is saved.
# Snapshot 743 is saved.
# Snapshot 744 is saved.
# Snapshot 745 is saved.
# Snapshot 746 is saved.
# Snapshot 747 is saved.
# Snapshot 748 is saved.
# Snapshot 749 is saved.
# Snapshot 750 is saved.
# Snapshot 751 is saved.
# Snapshot 752 is saved.
# Snapshot 753 is saved.
# Snapshot 754 is saved.
# Snapshot 755 is saved.
# Snapshot 756 is saved.
# Snapshot 757 is saved.
# Snapshot 758 is saved.
# Snapshot 759 is saved.
# Snapshot 760 is saved.
# Snapshot 761 is saved.
# Snapshot 762 is saved.
# Snapshot 763 is saved.
# Snapshot 764 is saved.
# Snapshot 765 is saved.
# Snapshot 766 is saved.
# Snapshot 767 is saved.
# Snapshot 768 is saved.
# Snapshot 769 is saved.
# Snapshot 770 is saved.
# Snapshot 771 is saved.
# Snapshot 772 is saved.
# Snapshot 773 is saved.
# Snapshot 774 is saved.
# Snapshot 775 is saved.
# Snapshot 776 is saved.
# Snapshot 777 is saved.
# Snapshot 778 is saved.
# Snapshot 779 is saved.
# Snapshot 780 is saved.
# Snapshot 781 is saved.
# Snapshot 782 is saved.
# Snapshot 783 is saved.
# Snapshot 784 is saved.
# Snapshot 785 is saved.
# Snapshot 786 is saved.
# Snapshot 787 is saved.
# Snapshot 788 is saved.
# Snapshot 789 is saved.
# Snapshot 790 is saved.
# Snapshot 791 is saved.
# Snapshot 792 is saved.
# Snapshot 793 is saved.
# Snapshot 794 is saved.
# Snapshot 795 is saved.
# Snapshot 796 is saved.
# Snapshot 797 is saved.
# Snapshot 798 is saved.
# Snapshot 799 is saved.
# Snapshot 800 is saved.
# Snapshot 801 is saved.
# Snapshot 802 is saved.
# Snapshot 803 is saved.
# Snapshot 804 is saved.
# Snapshot 805 is saved.
# Snapshot 806 is saved.
# Snapshot 807 is saved.
# Snapshot 808 is saved.
# Snapshot 809 is saved.
# Snapshot 810 is saved.
# Snapshot 811 is saved.
# Snapshot 812 is saved.
# Snapshot 813 is saved.
# Snapshot 814 is saved.
# Snapshot 815 is saved.
# Snapshot 816 is saved.
# Snapshot 817 is saved.
# Snapshot 818 is saved.
# Snapshot 819 is saved.
# Snapshot 820 is saved.
# Snapshot 821 is saved.
# Snapshot 822 is saved.
# Snapshot 823 is saved.
# Snapshot 824 is saved.
# Snapshot 825 is saved.
# Snapshot 826 is saved.
# Snapshot 827 is saved.
# Snapshot 828 is saved.
# Snapshot 829 is saved.
# Snapshot 830 is saved.
# Snapshot 831 is saved.
# Snapshot 832 is saved.
# Snapshot 833 is saved.
# Snapshot 834 is saved.
# Snapshot 835 is saved.
# Snapshot 836 is saved.
# Snapshot 837 is saved.
# Snapshot 838 is saved.
# Snapshot 839 is saved.
# Snapshot 840 is saved.
# Snapshot 841 is saved.
# Snapshot 842 is saved.
# Snapshot 843 is saved.
# Snapshot 844 is saved.
# Snapshot 845 is saved.
# Snapshot 846 is saved.
# Snapshot 847 is saved.
# Snapshot 848 is saved.
# Snapshot 849 is saved.
# Snapshot 850 is saved.
# Snapshot 851 is saved.
# Snapshot 852 is saved.
# Snapshot 853 is saved.
# Snapshot 854 is saved.
# Snapshot 855 is saved.
# Snapshot 856 is saved.
# Snapshot 857 is saved.
# Snapshot 858 is saved.
# Snapshot 859 is saved.
# Snapshot 860 is saved.
# Snapshot 861 is saved.
# Snapshot 862 is saved.
# Snapshot 863 is saved.
# Snapshot 864 is saved.
# Snapshot 865 is saved.
# Snapshot 866 is saved.
# Snapshot 867 is saved.
# Snapshot 868 is saved.
# Snapshot 869 is saved.
# Snapshot 870 is saved.
# Snapshot 871 is saved.
# Snapshot 872 is saved.
# Snapshot 873 is saved.
# Snapshot 874 is saved.
# Snapshot 875 is saved.
# Snapshot 876 is saved.
# Snapshot 877 is saved.
# Snapshot 878 is saved.
# Snapshot 879 is saved.
# Snapshot 880 is saved.
# Snapshot 881 is saved.
# Snapshot 882 is saved.
# Snapshot 883 is saved.
# Snapshot 884 is saved.
# Snapshot 885 is saved.
# Snapshot 886 is saved.
# Snapshot 887 is saved.
# Snapshot 888 is saved.
# Snapshot 889 is saved.
# Snapshot 890 is saved.
# Snapshot 891 is saved.
# Snapshot 892 is saved.
# Snapshot 893 is saved.
# Snapshot 894 is saved.
# Snapshot 895 is saved.
# Snapshot 896 is saved.
# Snapshot 897 is saved.
# Trial 0 Fit 8.00 Steps 897
# Postevauation: Average Fitness 8.00 Total Steps 897
